# %%
import pandas as pd
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders

# Constants
EXCEL_FILE = 'contacts.xlsx'  # Path to your Excel file
RESUME_FILE = 'Jahnvi_Dubey_Resume.pdf'    # Path to your resume PDF
EMAIL_COLUMN = 'Company_Email'  # Column name for email addresses
NAME_COLUMN = 'Company_Name'    # Column name for company names
YOUR_EMAIL = 'jahnvidubey99@gmail.com'  # Your email
YOUR_PASSWORD = 'Dubeyshachi1999@'        # Your email password

# Function to read company details from the Excel file
def get_company_details(excel_file, email_column, name_column):
    try:
        # Read the Excel file
        df = pd.read_excel(excel_file)
        # Get all company names and emails as lists
        companies = df[name_column].tolist()
        emails = df[email_column].tolist()
        return companies, emails
    except Exception as e:
        print("Error reading Excel file:", e)
        return [], []

# Function to send email with the resume attached
def send_email(recipient_email, company_name, resume_file):
    try:
        # Set up the MIME
        msg = MIMEMultipart()
        msg['From'] = YOUR_EMAIL
        msg['To'] = recipient_email
        msg['Subject'] = f"Application for Python Developer Position at {company_name}"

        # Email body
        body = f"""\
Dear HR,

I hope this email finds you well.

I am writing to express my interest in the Python Developer position at {company_name}. 
With 1+ year of experience in Python development and experience in FastAPI, Django, web scraping, ML, and data analysis, 
I am excited about the opportunity to contribute to your team.

Attached is my resume for your review. I look forward to discussing how my skills and background align with the needs of your team.

Thank you for considering my application.

Best regards,
Jahnvi Dubey
9131488473
"""
        msg.attach(MIMEText(body, 'plain'))

        # Attach the resume file
        with open(resume_file, 'rb') as attachment:
            part = MIMEBase('application', 'octet-stream')
            part.set_payload(attachment.read())
            encoders.encode_base64(part)
            part.add_header('Content-Disposition', f'attachment; filename={resume_file}')
            msg.attach(part)

        # Send the email
        with smtplib.SMTP('smtp.gmail.com', 587) as server:  # Update for your email provider
            server.starttls()
            server.login(YOUR_EMAIL, YOUR_PASSWORD)
            server.sendmail(YOUR_EMAIL, recipient_email, msg.as_string())
            print(f"Email sent successfully to {recipient_email} ({company_name})!")

    except Exception as e:
        print(f"Error sending email to {recipient_email} ({company_name}):", e)

# Main
if __name__ == "__main__":
    # Read company details from the Excel file
    companies, emails = get_company_details(EXCEL_FILE, EMAIL_COLUMN, NAME_COLUMN)

    # Loop through each company and send an email
    if companies and emails:
        for company, email in zip(companies, emails):
            send_email(email, company, RESUME_FILE)
    else:
        print("No company details found in the Excel file.")

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import pandas as pd
import os

# Email credentials - Use environment variables for security
YOUR_EMAIL = os.getenv('jahnvidubey99@gmail.com')
YOUR_APP_PASSWORD = os.getenv('xpbzvtxkfxnconbo')  # Use OAuth2 instead of app password

# Path to the Excel file and resume - Use environment variables or parameters
EXCEL_FILE = 'contacts.xlsx'  # Replace with your Excel file path
RESUME_FILE = 'Jahnvi_Dubey_Resume.pdf'  # Replace with your resume file path

def send_email(recipient_email, recipient_name):
    try:
        # Create email message
        msg = MIMEMultipart()
        msg['From'] = YOUR_EMAIL
        msg['To'] = recipient_email
        msg['Subject'] = "Application for Python Developer Position"

        # Email body
        body = f"""\
Dear {recipient_name},

I hope this email finds you well.

I am writing to express my interest in the Python Developer position at {recipient_name}. With 1+ year of experience in Python development and expertise in FastAPI, Django, web scraping, ML, and data analysis, I am excited about the opportunity to contribute to your team.

Attached is my resume for your review. I look forward to discussing how my skills and background align with the needs of your team.

Thank you for considering my application.

Best regards,  
Jahnvi Dubey  
9131488473  
"""
        msg.attach(MIMEText(body, 'plain'))

        # Attach resume
        with open(RESUME_FILE, 'rb') as attachment:
            part = MIMEBase('application', 'octet-stream')
            part.set_payload(attachment.read())
        encoders.encode_base64(part)
        part.add_header(
            'Content-Disposition',
            f'attachment; filename={RESUME_FILE.split("/")[-1]}'
        )
        msg.attach(part)

        # Connect to Gmail SMTP server
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()
        server.login(YOUR_EMAIL, YOUR_APP_PASSWORD)
        server.send_message(msg)
        server.quit()

        print(f"Email sent successfully to {recipient_email} ({recipient_name})!")

    except Exception as e:
        print(f"Error sending email to {recipient_email} ({recipient_name}): {e}")

# Read Excel file to get company names and emails
def main():
    df = pd.read_excel(EXCEL_FILE)
    for _, row in df.iterrows():
        company_name = row['Company_Name']
        company_email = row['Company_Email']
        send_email(company_email, company_name)

if __name__ == "__main__":
    main()

# %%
import pandas as pd
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import os

# Read the Excel file
excel_file = 'contacts.xlsx'  # Replace with the path to your Excel file
df = pd.read_excel(excel_file)

# Email credentials
sender_email = "jahnvidubey99@gmail.com"
password = "Dubeyshachi1999@"  # Use environment variables or secure storage for password

# Resume PDF to attach
resume_pdf = 'Jahnvi_Dubey_Resume.pdf'  # Replace with the path to your resume PDF

# Set up the SMTP server and send the email
def send_email(receiver_email, company_name):
    try:
        # Create the email message
        message = MIMEMultipart()
        message['From'] = sender_email
        message['To'] = receiver_email
        message['Subject'] = f"Job Application - Resume for {company_name}"

        # Email body
        body = f"Dear {company_name},\n\nPlease find attached my resume for your consideration.\n\nBest regards."
        message.attach(MIMEText(body, 'plain'))

        # Attach the resume PDF
        with open(resume_pdf, 'rb') as attachment:
            part = MIMEBase('application', 'octet-stream')
            part.set_payload(attachment.read())
            encoders.encode_base64(part)
            part.add_header('Content-Disposition', f"attachment; filename={os.path.basename(resume_pdf)}")
            message.attach(part)

        # Establish connection to Gmail's SMTP server
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()  # Encrypt the connection
        server.login(sender_email, password)

        # Send the email
        server.sendmail(sender_email, receiver_email, message.as_string())
        print(f"Email sent to {company_name} ({receiver_email}) successfully!")

    except Exception as e:
        print(f"Failed to send email to {company_name} ({receiver_email}): {e}")

    finally:
        server.quit()


# Iterate through the Excel rows and send emails
for index, row in df.iterrows():
    company_name = row['Company_Name']
    company_email = row['Company_Email']
    
    # Send the email with the resume
    send_email(company_email, company_name)

# %%
import pandas as pd
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
import os

# Read the Excel file
excel_file = 'contacts.xlsx'  # Replace with the path to your Excel file
df = pd.read_excel(excel_file)

# Email credentials (Use an App Password here instead of your regular password)
sender_email = "jahnvidubey99@gmail.com"
app_password = "xpbz vtxk fxnc onbo"  # Replace with the 16-character App Password you generated

# Resume PDF to attach
resume_pdf = 'Jahnvi_Dubey_Resume.pdf'  # Replace with the path to your resume PDF

# Set up the SMTP server and send the email
def send_email(receiver_email, company_name):
    try:
        # Create the email message
        message = MIMEMultipart()
        message['From'] = sender_email
        message['To'] = receiver_email
        message['Subject'] = f"Python Associate Software Developer Position - Jahnvi Dubey"

        # Email body
        body = (
            "Dear HR,\n\n"
            "I hope this email finds you well.\n\n"
            "I am writing to express my interest in the Python Developer position at {company_name}. "
            "With 1+ year of experience in Python development and experience in FastAPI, Django, web scraping, ML, "
            "and data analysis, I am excited about the opportunity to contribute to your team.\n\n"
            "Attached is my resume for your review. I look forward to discussing how my skills and background "
            "align with the needs of your team.\n\n"
            "Thank you for considering my application.\n\n"
            "Best regards,\n"
            "Jahnvi Dubey\n"
            "9131488473\n"
            "jahnvidubey99@gmail.com\n"
            "https://github.com/Jahnvidubey"
        ).format(company_name=company_name)
        message.attach(MIMEText(body, 'plain'))

        # Attach the resume PDF
        with open(resume_pdf, 'rb') as attachment:
            part = MIMEBase('application', 'octet-stream')
            part.set_payload(attachment.read())
            encoders.encode_base64(part)
            part.add_header('Content-Disposition', f"attachment; filename={os.path.basename(resume_pdf)}")
            message.attach(part)

        # Establish connection to Gmail's SMTP server
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.starttls()  # Encrypt the connection
        server.login(sender_email, app_password)  # Use the App Password here

        # Send the email
        server.sendmail(sender_email, receiver_email, message.as_string())
        print(f"Email sent to {company_name} ({receiver_email}) successfully!")

    except Exception as e:
        print(f"Failed to send email to {company_name} ({receiver_email}): {e}")

    finally:
        server.quit()


# Iterate through the Excel rows and send emails
for index, row in df.iterrows():
    company_name = row['Company_Name']
    company_email = row['Company_Email']
    
    # Send the email with the resume
    send_email(company_email, company_name)
# Out:
# Email sent to WebKorps (Damini@webkorps.com) successfully!
# Email sent to The Rapid Hire (aishwaryasharma.trh@gmail.com) successfully!
